# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Sample Image

# %%
sample_img = np.random.randint(0,10, size=(8,8), dtype='uint8')
print(sample_img)
plt.imshow(sample_img)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]

# %% [markdown]
# # Zoom out
#
# * Inter Nearest
#
# ` [0][0] gets the index, [0][1] drops the index, [0][2] gets the index, [0][3] drops the index ...... `
#
# ` [0][0] gets the index, [1][0] drops the index, [2][0] gets the index, [3][0] drops the index ...... `

# %%
zoom_out_nearest = cv2.resize(sample_img, (4,4), interpolation=cv2.INTER_NEAREST)
print(sample_img,"\n")

print(zoom_out_nearest)
plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Nearest Image")
plt.imshow(zoom_out_nearest)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[5 1 3 2]
#  [8 4 1 2]
#  [7 0 6 6]
#  [2 8 0 8]]

# %% [markdown]
# * Inter Linear
#
# ` [0][0]+[0][1]+[1][0]+[1][1] (indices change accordingly [0][2]+[0][3]+[1 ][2]+[1][3]) adds the numbers and takes the average and rounds up to the nearest `

# %%
zoom_out_linear = cv2.resize(sample_img, (4,4), interpolation=cv2.INTER_LINEAR)
print(sample_img,'\n')

print(zoom_out_linear)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Linear Image")
plt.imshow(zoom_out_linear)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[4 6 4 4]
#  [4 7 4 4]
#  [7 4 5 3]
#  [5 6 5 5]]

# %% [markdown]
# * Inter Area
#
# ` INTER_AREA [0][0]+[0][1]+[1][0]+[1][1] (indices change accordingly [0][2]+[0][3]+[1 ][2]+[1][3])
# adds the numbers and takes the average and rounds up to the nearest. `
#
# ` INTER_AREA and INTER_LINEAR work the same for reduction `

# %%
zoom_out_area = cv2.resize(sample_img, (4,4), interpolation=cv2.INTER_AREA)
print(sample_img,'\n')

print(zoom_out_area)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Area Image")
plt.imshow(zoom_out_area)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[4 6 4 4]
#  [4 7 4 4]
#  [7 4 5 3]
#  [5 6 5 5]]

# %% [markdown]
# * Inter Cubic

# %%
zoom_out_cubic = cv2.resize(sample_img, (4,4), interpolation=cv2.INTER_CUBIC)
print(sample_img,'\n')

print(zoom_out_cubic)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Cubic Image")
plt.imshow(zoom_out_cubic)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[4 7 4 5]
#  [4 8 3 3]
#  [8 3 6 2]
#  [4 6 5 6]]

# %% [markdown]
# * Inter LANCZOS4

# %%
zoom_out_LANCZOS4 = cv2.resize(sample_img, (4,4), interpolation=cv2.INTER_LANCZOS4)
print(sample_img,'\n')

print(zoom_out_LANCZOS4)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter LANCZOS4 Image")
plt.imshow(zoom_out_LANCZOS4)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[4 7 4 5]
#  [4 9 3 3]
#  [8 3 6 2]
#  [3 6 5 6]]

# %% [markdown]
# # Zoom in
#
# * Inter Nearset
#
# ` Each pixel is surrounded by the same pixel `

# %%
zoom_in_nearest = cv2.resize(sample_img, (16,16), interpolation=cv2.INTER_NEAREST)
print(sample_img,"\n")

print(zoom_in_nearest)
plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Nearest Image")
plt.imshow(zoom_in_nearest)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[5 5 5 5 1 1 5 5 3 3 3 3 2 2 1 1]
#  [5 5 5 5 1 1 5 5 3 3 3 3 2 2 1 1]
#  [0 0 5 5 9 9 9 9 2 2 9 9 8 8 6 6]
#  [0 0 5 5 9 9 9 9 2 2 9 9 8 8 6 6]
#  [8 8 0 0 4 4 8 8 1 1 5 5 2 2 4 4]
#  [8 8 0 0 4 4 8 8 1 1 5 5 2 2 4 4]
#  [9 9 0 0 8 8 8 8 6 6 3 3 6 6 3 3]
#  [9 9 0 0 8 8 8 8 6 6 3 3 6 6 3 3]
#  [7 7 6 6 0 0 6 6 6 6 4 4 6 6 3 3]
#  [7 7 6 6 0 0 6 6 6 6 4 4 6 6 3 3]
#  [6 6 8 8 8 8 3 3 5 5 6 6 2 2 1 1]
#  [6 6 8 8 8 8 3 3 5 5 6 6 2 2 1 1]
#  [2 2 4 4 8 8 1 1 0 0 6 6 8 8 5 5]
#  [2 2 4 4 8 8 1 1 0 0 6 6 8 8 5 5]
#  [8 8 4 4 7 7 6 6 9 9 6 6 0 0 8 8]
#  [8 8 4 4 7 7 6 6 9 9 6 6 0 0 8 8]]

# %% [markdown]
# * Inter Linear

# %%
zoom_in_linear = cv2.resize(sample_img, (16,16), interpolation=cv2.INTER_LINEAR)
print(sample_img,'\n')

print(zoom_in_linear)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Linear Image")
plt.imshow(zoom_in_linear)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[5 5 5 4 2 2 4 4 3 3 3 3 2 2 1 1]
#  [4 4 5 5 4 4 5 5 3 3 4 4 4 3 2 2]
#  [1 2 4 6 7 7 8 6 4 4 6 7 7 6 5 5]
#  [2 2 3 5 7 8 9 7 3 3 6 8 7 6 6 6]
#  [6 5 2 2 4 6 8 6 3 2 5 5 4 4 4 5]
#  [8 6 2 1 4 6 7 6 4 3 4 4 3 3 3 4]
#  [9 7 2 2 5 7 8 7 5 4 4 4 4 4 4 3]
#  [9 7 3 3 5 6 7 7 6 5 4 4 5 5 4 3]
#  [8 7 5 4 3 3 5 6 6 5 4 4 5 5 4 3]
#  [7 7 6 5 3 3 4 5 6 5 5 5 5 4 3 3]
#  [6 6 7 7 6 5 4 4 5 5 5 5 4 3 2 2]
#  [5 5 6 7 8 7 4 3 3 4 5 5 4 3 2 2]
#  [3 3 4 6 7 6 3 1 1 2 5 6 6 6 5 4]
#  [4 4 4 5 7 6 4 2 2 3 5 6 6 6 6 6]
#  [7 6 5 5 6 7 5 5 6 6 6 5 3 3 6 7]
#  [8 7 5 5 6 7 6 7 8 8 7 4 1 2 6 8]]

# %% [markdown]
# * Inter Area

# %%
zoom_in_area = cv2.resize(sample_img, (16,16), interpolation=cv2.INTER_AREA)
print(sample_img,'\n')

print(zoom_in_area)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Area Image")
plt.imshow(zoom_in_area)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[5 5 5 5 1 1 5 5 3 3 3 3 2 2 1 1]
#  [5 5 5 5 1 1 5 5 3 3 3 3 2 2 1 1]
#  [0 0 5 5 9 9 9 9 2 2 9 9 8 8 6 6]
#  [0 0 5 5 9 9 9 9 2 2 9 9 8 8 6 6]
#  [8 8 0 0 4 4 8 8 1 1 5 5 2 2 4 4]
#  [8 8 0 0 4 4 8 8 1 1 5 5 2 2 4 4]
#  [9 9 0 0 8 8 8 8 6 6 3 3 6 6 3 3]
#  [9 9 0 0 8 8 8 8 6 6 3 3 6 6 3 3]
#  [7 7 6 6 0 0 6 6 6 6 4 4 6 6 3 3]
#  [7 7 6 6 0 0 6 6 6 6 4 4 6 6 3 3]
#  [6 6 8 8 8 8 3 3 5 5 6 6 2 2 1 1]
#  [6 6 8 8 8 8 3 3 5 5 6 6 2 2 1 1]
#  [2 2 4 4 8 8 1 1 0 0 6 6 8 8 5 5]
#  [2 2 4 4 8 8 1 1 0 0 6 6 8 8 5 5]
#  [8 8 4 4 7 7 6 6 9 9 6 6 0 0 8 8]
#  [8 8 4 4 7 7 6 6 9 9 6 6 0 0 8 8]]

# %% [markdown]
# * Inter Cubic

# %%
zoom_in_cubic = cv2.resize(sample_img, (16,16), interpolation=cv2.INTER_AREA)
print(sample_img,'\n')

print(zoom_in_cubic)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter Cubic Image")
plt.imshow(zoom_in_cubic)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[5 5 5 5 1 1 5 5 3 3 3 3 2 2 1 1]
#  [5 5 5 5 1 1 5 5 3 3 3 3 2 2 1 1]
#  [0 0 5 5 9 9 9 9 2 2 9 9 8 8 6 6]
#  [0 0 5 5 9 9 9 9 2 2 9 9 8 8 6 6]
#  [8 8 0 0 4 4 8 8 1 1 5 5 2 2 4 4]
#  [8 8 0 0 4 4 8 8 1 1 5 5 2 2 4 4]
#  [9 9 0 0 8 8 8 8 6 6 3 3 6 6 3 3]
#  [9 9 0 0 8 8 8 8 6 6 3 3 6 6 3 3]
#  [7 7 6 6 0 0 6 6 6 6 4 4 6 6 3 3]
#  [7 7 6 6 0 0 6 6 6 6 4 4 6 6 3 3]
#  [6 6 8 8 8 8 3 3 5 5 6 6 2 2 1 1]
#  [6 6 8 8 8 8 3 3 5 5 6 6 2 2 1 1]
#  [2 2 4 4 8 8 1 1 0 0 6 6 8 8 5 5]
#  [2 2 4 4 8 8 1 1 0 0 6 6 8 8 5 5]
#  [8 8 4 4 7 7 6 6 9 9 6 6 0 0 8 8]
#  [8 8 4 4 7 7 6 6 9 9 6 6 0 0 8 8]]

# %% [markdown]
# * Inter LANCZOS4

# %%
zoom_in_LANCZOS4 = cv2.resize(sample_img, (16,16), interpolation=cv2.INTER_LANCZOS4)
print(sample_img,'\n')

print(zoom_in_LANCZOS4)

plt.figure(figsize=(5,5))

plt.subplot(121)
plt.title("Sample Image")
plt.imshow(sample_img)

plt.subplot(122)
plt.title("Inter LANCZOS4 Image")
plt.imshow(zoom_in_LANCZOS4)
# Out:
# [[5 5 1 5 3 3 2 1]
#  [0 5 9 9 2 9 8 6]
#  [8 0 4 8 1 5 2 4]
#  [9 0 8 8 6 3 6 3]
#  [7 6 0 6 6 4 6 3]
#  [6 8 8 3 5 6 2 1]
#  [2 4 8 1 0 6 8 5]
#  [8 4 7 6 9 6 0 8]]
#
# [[ 6  6  6  3  0  0  3  5  4  2  2  2  1  1  0  0]
#  [ 3  4  5  5  3  4  6  6  4  3  4  5  4  3  2  2]
#  [ 0  1  4  6  8  9  9  7  3  3  6  9  8  7  5  5]
#  [ 1  2  3  5  7 10 10  7  2  2  7 10  8  6  6  6]
#  [ 6  5  2  1  3  7  9  6  2  1  5  7  4  3  4  5]
#  [11  7  1  0  2  7  9  6  3  2  3  4  2  2  3  4]
#  [11  7  1  0  5  9  9  7  6  4  3  3  4  4  3  3]
#  [ 9  6  2  2  5  8  8  8  7  5  3  4  7  7  4  3]
#  [ 7  7  6  3  1  2  5  8  7  5  3  4  7  7  5  3]
#  [ 7  8  8  6  2  1  4  6  7  6  5  4  4  4  3  2]
#  [ 7  7  8  8  7  5  4  4  5  6  6  5  3  1  1  1]
#  [ 5  5  6  8 10  8  4  1  2  5  6  6  4  3  2  1]
#  [ 2  2  3  6  9  8  3  0  0  1  5  7  8  6  4  3]
#  [ 3  3  3  5  7  7  4  1  1  3  5  7  7  7  6  6]
#  [ 7  6  4  4  6  7  5  5  6  7  7  5  2  3  6  8]
# ...
